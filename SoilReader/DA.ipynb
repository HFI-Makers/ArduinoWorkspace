# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DATA.CSV")
df.columns
# Out:
# Index(['Time', ' Reading1', ' Reading2'], dtype='object')

# %%
df.replace(r' ', np.NaN)
df.dropna()
# Out:
#            Time   Reading1   Reading2
# 0           268        414        616
# 1           788        419        618
# 2          1308        423        621
# 3          1828        428        620
# 4          2348        430        620
# ...         ...        ...        ...
# 98260  51095468        541        563
# 98261  51095988        541        562
# 98262  51096508        543        561
# 98263  51097028        541        562
# 98264  51097548        545        566
#
# [98265 rows x 3 columns]

# %%
frame = pd.DataFrame(df)
frame.to_csv("processed.csv")

# %%
x = df.iloc[:, 0]
r1 = df.iloc[:, 1]
r2 = df.iloc[:, 2]

# %%
plt.figure(figsize=(64, 32), dpi=500, facecolor='w')
plt.scatter(x, r1, color='r')
plt.scatter(x, r2, color='b')
plt.ylabel("Reading", fontdict={'size': 45})
plt.xlabel("Time", fontdict={'size': 45})
plt.tick_params(labelsize=40)
plt.show()
