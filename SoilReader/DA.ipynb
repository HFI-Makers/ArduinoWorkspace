# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read file name, must be a csv
df = pd.read_csv("Sept27_28Data.csv")
df.columns
# Out:
# Index(['Time', ' Reading1', ' Reading2'], dtype='object')

# %%
df.replace(r' ', np.NaN)
df.dropna()
# Out:
#             Time   Reading1   Reading2
# 0            268        414        616
# 1            788        419        618
# 2           1308        423        621
# 3           1828        428        620
# 4           2348        430        620
# ...          ...        ...        ...
# 162908  84712948        543        570
# 162909  84713468        541        571
# 162910  84713988        540        571
# 162911  84714508        541        571
# 162912  84715028        541        571
#
# [162913 rows x 3 columns]

# %%
x = df.iloc[:, 0]
r1 = df.iloc[:, 1]
r2 = df.iloc[:, 2]

# %%
plt.figure(figsize=(80, 20), dpi=256, facecolor='w')
plt.scatter(x, r1, color='r')
plt.scatter(x, r2, color='b')
plt.ylabel("Reading", fontdict={'size': 45})
plt.xlabel("Time", fontdict={'size': 45})
plt.tick_params(labelsize=40)
plt.savefig("Sept27_28.png")
plt.show()
